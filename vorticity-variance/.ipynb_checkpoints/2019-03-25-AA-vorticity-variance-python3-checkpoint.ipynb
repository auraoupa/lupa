# %% [markdown]
# # Fine scale variance of surface relative vorticity
#
#
# __author__ : Aurélie Albert & Julien Le Sommer (MEOM)
#
# __context__ : 22-GLO-HR project : Lot 1 - Ocean Modelling
#
# __date__ : 30 May 2017
#
# __purpose__ : Metric for the intensity of the fine scale of surface relative vorticity in NATL60-CJM165 simulation
#
# __detailed description__ :
# Fine scale variance is defined at a given time and space by :
#
# $$V(X) = (X - \langle X \rangle)^{2}$$
#
# with $\langle . \rangle$ the low pass filtering operator. An average in time and space of the variance is then defined as :
#
# $$\overline{(X(t)-\langle X \rangle)^{2}}^{t,x,y}$$
#
# with $\overline{X}^{t,x,y}$ a boxcar averager.
#
# __practical steps__ :
#
#   * Input data are NATL60-CJM165 daily outputs of surface relative vorticity (computed from U and V fields with cdfcurl cdftool : https://github.com/meom-group/CDFTOOLS) for the month March and September 2013
#   * step 1. : Snapshots of relative vorticity (15 March - 15 October 2013 )
#   * step 2. : Filtering of input data is performed with Lanczos2DHighPassFilter.py on command line so that the filtered signal is kept in netcdf files equivalent to input data
#   * step 3. : Variance of the high-pass filtered relative surface vorticity and boxcar averaging in 1°x1°x1 month boxes
#   * step 4. : Maps of fine scale variance of relative vorticity in March and October 2013
#
# __external libraries needed to run this script__ :
#
#  * GriddedData : https://github.com/lesommer/codes/blob/master/GriddedData.py
#  * WavenumberSpectrum : https://github.com/lesommer/codes/blob/master/WavenumberSpectrum.py
#  * oocgcm filtering module : https://github.com/lesommer/oocgcm
#
# __licence__ : This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Creative Commons Attribution 4.0 International License</a>.

# %%
## path for mdules

import sys
sys.path.insert(0,"/home/albert/Work/git/lupa/lib")

# %%
## imports

import numpy as np
import xarray as xr
import GriddedData
import time

# %%
#- Other modules
import numpy.ma as ma
import WavenumberSpectrum as ws

# %%
### palette
import matplotlib.cm as mplcm

seq_cmap = mplcm.Blues
div_cmap = mplcm.seismic

### quick plot
import matplotlib.pyplot as plt

# %%
## local/specific imports
import linearfilters as tf
# %matplotlib inline

# %% [markdown]
# ## 1. Snapshots of relative vorticity (15 March - 15 October 2013 )

# %%
## Dataset

dir="/mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/"
dirf="/mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/"
dirin="/mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-I/"

files03="NATL60-CJM165_y2013m03d*.1d_curloverf.nc"
files09="NATL60-CJM165_y2013m09d*.1d_curloverf.nc"

tfiles03=dir+files03
tfiles09=dir+files09

# !ls $tfiles03
# !ls $tfiles09
# Out:
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d01.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d02.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d03.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d04.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d05.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d06.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d07.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d08.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d09.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d10.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d11.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d12.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d13.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d14.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d15.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d16.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d17.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d18.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d19.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d20.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d21.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d22.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d23.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d24.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d25.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d26.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d27.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d28.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d29.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d30.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m03d31.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d01.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d02.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d03.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d04.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d05.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d06.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d07.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d08.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d09.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d10.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d11.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d12.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d13.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d14.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d15.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d16.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d17.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d18.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d19.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d20.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d21.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d22.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d23.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d24.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d25.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d26.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d27.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d28.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d29.1d_curloverf.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/curl/NATL60-CJM165_y2013m09d30.1d_curloverf.nc

# %%
gridfile=dirin+"NATL60_v4.1_cdf_byte_mask.nc"
# !ls $gridfile
grid=xr.open_dataset(gridfile)
navlat= grid['nav_lat']
navlon= grid['nav_lon']
# Out:
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-I/NATL60_v4.1_cdf_byte_mask.nc

# %%
def load_and_plot(tfile,title):
    '''  load one daily file and plot the surface field
        
    '''
    curls = xr.open_dataset(tfile)
    curl15=curls['socurloverf'][0]
    navlat= curls['nav_lat']
    navlon= curls['nav_lon']
    cont=np.isnan(curl15)
    
    plt.figure(figsize=(15,11))
    ax = plt.subplot(111)
    ax.autoscale(tight=True)
    pcolor = ax.pcolormesh(navlon,navlat,
      ma.masked_invalid(curl15),cmap=div_cmap,vmin=-1,vmax=1,alpha=1)
    ax.tick_params(labelsize=25)
    ax.contour(navlon,navlat,cont,alpha=0.5,linewidths=1,colors='k',antialiased=True)
    cbar = plt.colorbar(pcolor,orientation='horizontal',pad=0.1)
    cbar.ax.tick_params(labelsize=35)
    ax.set_xlabel('Longitude (in degree)',fontsize=20)
    ax.set_ylabel('Latitude (in degree)',fontsize=20)
    cbar.ax.tick_params(labelsize=25)
    plt.title(title,fontsize=25)

# %%
files0315="NATL60-CJM165_y2013m03d15.1d_curloverf.nc"
tfiles0315=dir+files0315

load_and_plot(tfiles0315,'Relative surface vorticity NATL60-CJM165 15-March-2013')

# %%
files0915="NATL60-CJM165_y2013m09d15.1d_curloverf.nc"
tfiles0915=dir+files0915

load_and_plot(tfiles0915,'Relative surface vorticity NATL60-CJM165 15-September-2013')

# %% [markdown]
# ## 2. Filtering of input data

# %% [markdown]
# We used Lanczos2DHighPassFilter.py script to filter vorticity files with the options n=80 (size of Lanczos window) and f=0.0125 (cut-off frequency) :
#
# ```
# python Lanczos2DHighPassFilter.py -v 'socurloverf' -s  /media/extra/DATA/NATL60/NATL60-CJM165-S/NATL60-CJM165_y2013m03d*.1d_curloverf.nc 80 0.0125
# ```
#
# These parameters have been chosen for NATL60 outputs, they have to be tuned regarding the resolution of the data.
# A spectra of the resulting filtered signal compared to the total signal confirm that the filter has the wanted effective cut-off frequency and a clean energy separation.

# %%
# compute the spectra over 10°x10° box for one example file

test_file="NATL60-CJM165_y2013m03d01.1d_curloverf.nc"
tf_test_file="NATL60-CJM165_y2013m03d01.1d_curloverf_filt-n80-f0.0125.nc"
test=dir+test_file
tf_test=dirf+tf_test_file


ds = xr.open_dataset(test)
hpds = xr.open_dataset(tf_test)
grid=xr.open_dataset(gridfile)

navlon = np.array(grid["nav_lon"]).squeeze()
navlat = np.array(grid["nav_lat"]).squeeze()

curl = ds['socurloverf']
hpcurl = hpds['socurloverf_filt']


zfull = curl[0,600:1200,1800:2400].values # si pas .values plot ok mais ne peut pas calculer le spectre
zfull[np.where(np.isnan(zfull))]=0. # 0. are missing values so they are converted to nan

zhp = hpcurl[0,600:1200,1800:2400].values
zhp[np.where(np.isnan(zhp))]=0. # 0. are missing values so they are converted to nan

zlp = zfull - zhp

zlon = navlon[600:1200,1800:2400]
zlat = navlat[600:1200,1800:2400]

#- compute the wavenumber spectrum
interp = 'basemap'

# %%
import numpy.fft as fft
def get_spectrum_1d(data_reg,x_reg,y_reg):
    """Compute the 1d power spectrum.
    """
    # remove the mean and squarize
    data_reg-=data_reg.mean()
    jpj,jpi = data_reg.shape
    msize = min(jpj,jpi)
    data_reg = data_reg[:msize-1,:msize-1]
    x_reg = x_reg[:msize-1,:msize-1]
    y_reg = y_reg[:msize-1,:msize-1]
    # wavenumber vector
    x1dreg,y1dreg = x_reg[0,:],y_reg[:,0]
    Ni,Nj = msize-1,msize-1
    dx=np.int(np.ceil(x1dreg[1]-x1dreg[0]))
    k_max  = np.pi / dx
    kx = fft.fftshift(fft.fftfreq(Ni, d=1./(2.*k_max)))
    ky = fft.fftshift(fft.fftfreq(Nj, d=1./(2.*k_max)))
    kkx, kky = np.meshgrid( ky, kx )
    Kh = np.sqrt(kkx**2 + kky**2)
    Nmin  = min(Ni,Nj)
    leng  = np.int(Nmin//2+1)
    kstep = np.zeros(leng)
    kstep[0] =  k_max / Nmin
    for ind in range(1, leng):
        kstep[ind] = kstep[ind-1] + 2*k_max/Nmin
    norm_factor = 1./( (Nj*Ni)**2 )
    # tukey windowing = tapered cosine window
    cff_tukey = 0.25
    yw=np.linspace(0, 1, Nj)
    wdw_j = np.ones(yw.shape)
    xw=np.linspace(0, 1, Ni)
    wdw_i= np.ones(xw.shape)
    first_conditioni = xw<cff_tukey/2
    first_conditionj = yw<cff_tukey/2
    wdw_i[first_conditioni] = 0.5 * (1 + np.cos(2*np.pi/cff_tukey * (xw[first_conditioni] - cff_tukey/2) ))
    wdw_j[first_conditionj] = 0.5 * (1 + np.cos(2*np.pi/cff_tukey * (yw[first_conditionj] - cff_tukey/2) ))
    third_conditioni = xw>=(1 - cff_tukey/2)
    third_conditionj = yw>=(1 - cff_tukey/2)
    wdw_i[third_conditioni] = 0.5 * (1 + np.cos(2*np.pi/cff_tukey * (xw[third_conditioni] - 1 + cff_tukey/2)))
    wdw_j[third_conditionj] = 0.5 * (1 + np.cos(2*np.pi/cff_tukey * (yw[third_conditionj] - 1 + cff_tukey/2)))
    wdw_ii, wdw_jj = np.meshgrid(wdw_j, wdw_i, sparse=True)
    wdw = wdw_ii * wdw_jj
    data_reg*=wdw
    #2D spectrum
    cff  = norm_factor
    tempconj=fft.fft2(data_reg).conj()
    tempamp=cff * np.real(tempconj*fft.fft2(data_reg))
    spec_2d=fft.fftshift(tempamp)
    #1D spectrum
    leng    = len(kstep)
    spec_1d = np.zeros(leng)
    krange     = Kh <= kstep[0]
    spec_1d[0] = spec_2d[krange].sum()
    for ind in range(1, leng):
        krange = (kstep[ind-1] < Kh) & (Kh <= kstep[ind])
        spec_1d[ind] = spec_2d[krange].sum()
    spec_1d[0] /= kstep[0]
    for ind in range(1, leng):
        spec_1d[ind] /= kstep[ind]-kstep[ind-1]
    return spec_1d, kstep

def compute_spectrum(var):
    data = var.squeeze()
    x_reg,y_reg,data_reg = ws.interpolate(data,zlon,zlat,interp=interp)
    pspec,kstep = get_spectrum_1d(data_reg,x_reg,y_reg)
    return pspec, kstep

# %%
spectre_full = compute_spectrum(zfull)

# %%
# %time spectre_full = compute_spectrum(zfull)
# %time spectre_hp   = compute_spectrum(zhp)
# %time spectre_lp   = compute_spectrum(zlp)
# Out:
# CPU times: user 1.69 s, sys: 84 ms, total: 1.78 s
# Wall time: 641 ms
# CPU times: user 1.53 s, sys: 44 ms, total: 1.58 s
# Wall time: 527 ms
# CPU times: user 1.52 s, sys: 52 ms, total: 1.58 s
# Wall time: 518 ms

# %%
#- plot the mean spectrum 
rad2cyc = 1.E3 / np.pi / 2. 

def nice_spectrum(spectre_full,spectre_hp,spectre_lp):
    fig, axarr = plt.subplots(1,1)
    fig.set_figheight(8)
    fig.set_figwidth(15)
    #
    pspec,kstep = spectre_full
    pspec_lp,kstep_lp = spectre_lp
    pspec_hp,kstep_hp = spectre_hp
    skstep = kstep * rad2cyc
    y_min = 10 ** np.floor(np.log10(pspec.min())-1)
    y_max = 10 ** np.ceil( np.log10(pspec.max())+1)
    axarr.plot(skstep[1:], pspec[1:],'k-', lw=3, label='Full relative vorticity')
    axarr.plot(skstep[1:], pspec_lp[1:],'r-', lw=3, label='Low passed relative vorticity f=0.0125 n=80')
    axarr.plot(skstep[1:], pspec_hp[1:],'b-', lw=3, label='Full - Low passed  f=0.0125 n=80')
    axarr.set_xscale('log')
    axarr.set_yscale('log')
    axarr.set_xbound(1e-5*rad2cyc, 1e-2*rad2cyc)
    axarr.set_ybound(y_min, y_max)
    axarr.set_title('',fontsize=20)
    axarr.grid(True,which='both',ls='-')
    axarr.axis('tight')
    axarr.legend(loc="lower left", fontsize=25)
    axarr.tick_params(labelsize=25)

# %%
nice_spectrum(spectre_full,spectre_hp,spectre_lp)

# %%
filt_files03="NATL60-CJM165_y2013m03d*.1d_curloverf_filt-n80-f0.0125.nc"
filt_files09="NATL60-CJM165_y2013m09d*.1d_curloverf_filt-n80-f0.0125.nc"

tf_files03=dirf+filt_files03
tf_files09=dirf+filt_files09

# !ls $tf_files03
# !ls $tf_files09
# Out:
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d01.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d02.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d03.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d04.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d05.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d06.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d07.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d08.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d09.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d10.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d11.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d12.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d13.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d14.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d15.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d16.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d17.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d18.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d19.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d20.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d21.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d22.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d23.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d24.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d25.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d26.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d27.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d28.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d29.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d30.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m03d31.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d01.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d02.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d03.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d04.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d05.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d06.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d07.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d08.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d09.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d10.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d11.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d12.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d13.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d14.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d15.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d16.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d17.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d18.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d19.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d20.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d21.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d22.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d23.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d24.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d25.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d26.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d27.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d28.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d29.1d_curloverf_filt-n80-f0.0125.nc
# /mnt/albert/equipes/IGE/meom/workdir/albert/NATL60/NATL60-CJM165-S/1d/filt-surf/NATL60-CJM165_y2013m09d30.1d_curloverf_filt-n80-f0.0125.nc

# %% [markdown]
# ## 3. Variance of the high-pass filtered relative surface vorticity and boxcar averaging in 1°x1°x1 month boxes

# %%
def fine_scale_variance(files):
    ''' from a list of files containing one month of data compute variance and average in 1°x1°x1 month boxes
    '''
    hpcurl = xr.open_mfdataset(files,concat_dim='time_counter',decode_times=False)['socurloverf_filt']
    hpcurl2 = hpcurl ** 2
    hpcurl2m = hpcurl2.mean(axis=0,keep_attrs=True)
    navlat2=np.array(navlat).squeeze()
    navlon2=np.array(navlon).squeeze()
    mgrd = GriddedData.grid2D(navlat=navlat2, navlon=navlon2)
    crs = GriddedData.grdCoarsener(mgrd,crs_factor=60)
    hpcurl2mc = crs.return_ravel(np.asarray(hpcurl2m))
    hpcurl2mcm = np.mean(hpcurl2mc,axis=-3)
    latcrs=crs.return_ravel(np.asarray(navlat2))
    loncrs=crs.return_ravel(np.asarray(navlon2))
    latcrsm=np.mean(latcrs,axis=-3)
    loncrsm=np.mean(loncrs,axis=-3)
    return loncrsm,latcrsm,hpcurl2mcm,hpcurl2m

# %%
loncrsm03, latcrsm03, boxvarcurl03, hpvarm03 = fine_scale_variance(tf_files03)
# Out:
# /home/albert/anaconda2/envs/lupa-py3/lib/python3.7/site-packages/xarray/core/nanops.py:161: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/lupa-py3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#
# TypeError: 'float' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-07559169947a> in <module>
# ----> 1 loncrsm03, latcrsm03, boxvarcurl03, hpvarm03 = fine_scale_variance(tf_files03)
#
# <ipython-input-76-a6a121c8ed94> in fine_scale_variance(files)
#       8     navlon2=np.array(navlon).squeeze()
#       9     mgrd = GriddedData.grid2D(navlat=navlat2, navlon=navlon2)
# ---> 10     crs = GriddedData.grdCoarsener(mgrd,crs_factor=60)
#      11     hpcurl2mc = crs.return_ravel(np.asarray(hpcurl2m))
#      12     hpcurl2mcm = np.mean(hpcurl2mc,axis=-3)
#
# ~/Work/git/lupa/lib/GriddedData.py in __init__(self, grdin, x_offset, y_offset, crs_factor)
#     587         self.cut_array = lambda array2D:array2D[...,y_offset:jsize,x_offset:isize]
#     588         self.weights = self.cut_array(self.fine_grid.t_surf)
# --> 589         self.crs_area = boxcar_sum(self.weights,icrs=self.crs_factor,jcrs=self.crs_factor)
#     590         self.crs_shape = self.crs_area.shape
#     591
#
# ~/Work/git/lupa/lib/GriddedData.py in boxcar_sum(array2D, icrs, jcrs)
#     565     jpj, jpi = array2D.shape
#     566     shape = (jpj/jcrs, jpi/icrs)
# --> 567     sum_array = boxcar_ravel(array2D,icrs=icrs,jcrs=jcrs).sum(axis=0)
#     568     return sum_array
#     569
#
# ~/Work/git/lupa/lib/GriddedData.py in boxcar_ravel(array2D, icrs, jcrs)
#     539        print("shape and coarsening factors are not compatible")
#     540        return
# --> 541     reshaped = boxcar_reshape(array2D,icrs=icrs,jcrs=jcrs)
#     542     dum,dum,jpj,jpi = reshaped.shape
#     543     raveled = reshaped.reshape((icrs*jcrs,jpj,jpi))
#
# ~/Work/git/lupa/lib/GriddedData.py in boxcar_reshape(array2D, icrs, jcrs)
#     527     t = np.reshape(array2D,(jpj,-1,icrs))               # (jpj, jpi/icrs, icrs)
#     528     tt = t.swapaxes(0,2)                                # (icrs,jpi/icrs, jpi)
# --> 529     ttt = np.reshape(tt,(icrs,jpi/icrs,-1,jcrs))        # (icrs,jpi/icrs,jpj/jcrs, jcrs)
#     530     tttt = ttt.swapaxes(1,3)                            # (icrs,jcrs,jpj/jcrs, jpi/icrs)
#     531     ttttt = tttt.swapaxes(0,1)                          # (jcrs,icrs,jpj/jcrs, jpi/icrs)
#
# ~/anaconda2/envs/lupa-py3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     290            [5, 6]])
#     291     """
# --> 292     return _wrapfunc(a, 'reshape', newshape, order=order)
#     293
#     294
#
# ~/anaconda2/envs/lupa-py3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      64     # a downstream library like 'pandas'.
#      65     except (AttributeError, TypeError):
# ---> 66         return _wrapit(obj, method, *args, **kwds)
#      67
#      68
#
# ~/anaconda2/envs/lupa-py3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      44     except AttributeError:
#      45         wrap = None
# ---> 46     result = getattr(asarray(obj), method)(*args, **kwds)
#      47     if wrap:
#      48         if not isinstance(result, mu.ndarray):
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
loncrsm09, latcrsm09, boxvarcurl09, hpvarm09  = fine_scale_variance(tf_files09)

# %% [markdown]
# ## 4. Maps of fine scale variance of relative vorticity in March and October 2013

# %%
def plot_fine_scale_variance(var,loncrs,latcrs,lon,lat,hpvarm,month):
    ''' map of the averaged fine scale variance
    '''
    fig = plt.figure(figsize=(15,11))
    ax = plt.subplot(111)
    ax.autoscale(tight=True)
    cont=np.isnan(hpvarm)

    pcolor = ax.pcolormesh(loncrs,latcrs,ma.masked_invalid(var),cmap=seq_cmap,vmin=0,vmax=0.1,alpha=1)
    ax.tick_params(labelsize=25)
    ax.contour(lon,lat,cont,alpha=0.5,linewidth=0.000001,antialiased=True)
    cbar = plt.colorbar(pcolor,orientation='horizontal',pad=0.1)
    cbar.ax.tick_params(labelsize=35)
    ax.set_xlabel('Longitude (in degree)',fontsize=20)
    ax.set_ylabel('Latitude (in degree)',fontsize=20)
    cbar.ax.tick_params(labelsize=25)
    cbar.set_label('Small scales relative vorticity variance in '+month,fontsize=25)
    plt.savefig('fine_scale_variance_socurloverf_NATL60-CJM165_'+month+'.png')

# %%
plot_fine_scale_variance(boxvarcurl03,loncrsm03, latcrsm03,navlon,navlat,hpvarm03,'March')

# %%
plot_fine_scale_variance(boxvarcurl09,loncrsm09, latcrsm09,navlon,navlat,hpvarm09,'September')
